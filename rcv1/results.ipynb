# %% [markdown]
# # Plots of Classification Results
#
# Load imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# %% [markdown]
# Create arrays containing the data.

# %%
training_set_sizes_proportional = [12, 60, 120, 600, 1200, 6000, 12000, 60000, 72488]
training_set_sizes_balanced = [12, 60, 120, 600, 1200, 6000]

#---------------------------
#Results for kb2_proportional

kb2_proportional_micro = [0.5774, 0.7919, 0.8445, 0.9091, 0.9220, 0.9408, 0.9461, 0.9557, 0.9566]
kb2_proportional_macro = [0.2579, 0.5036, 0.6181, 0.7947, 0.8349, 0.8911, 0.9052, 0.9276, 0.9298]
kb2_proportional_micro_std = [0.1116, 0.0444, 0.0305, 0.0074, 0.0044, 0.0024, 0.0019, 0.0014, 0.0013]
kb2_proportional_macro_std = [0.0860, 0.1002, 0.0711, 0.0287, 0.0158, 0.0064, 0.0041, 0.0029, 0.0025]

#---------------------------
#Results for kb0_balanced

kb0_balanced_micro = [0.7316, 0.8707, 0.8855, 0.9058, 0.9118, 0.9224]
kb0_balanced_macro = [0.6436, 0.8014, 0.8190, 0.8445, 0.8525, 0.8675]
kb0_balanced_micro_std = [0.0613, 0.0176, 0.0118, 0.0056, 0.0048, 0.0023]
kb0_balanced_macro_std = [0.0613, 0.0210, 0.0151, 0.0080, 0.0074, 0.0041]

#---------------------------
#Results for kb1_balanced

kb1_balanced_micro = [0.6474, 0.8785, 0.8986, 0.9220, 0.9273, 0.9369]
kb1_balanced_macro = [0.5609, 0.8151, 0.8399, 0.8722, 0.8801, 0.8950]
kb1_balanced_micro_std = [0.0772, 0.0161, 0.0101, 0.0035, 0.0031, 0.0018]
kb1_balanced_macro_std = [0.0654, 0.0198, 0.0124, 0.0063, 0.0055, 0.0032]

#---------------------------
#Results for nb_balanced

nb_balanced_micro = [0.6028, 0.7926, 0.8426, 0.9024, 0.9151, 0.9339]
nb_balanced_macro = [0.5211, 0.7172, 0.7735, 0.8461, 0.8626, 0.8898]
nb_balanced_micro_std = [0.0833, 0.0398, 0.0230, 0.0080, 0.0052, 0.0025]
nb_balanced_macro_std = [0.0637, 0.0359, 0.0232, 0.0106, 0.0074, 0.0041]

#---------------------------
#Results for kb0_proportional

kb0_proportional_micro = [0.7140, 0.8789, 0.9027, 0.9233, 0.9285, 0.9368, 0.9393, 0.9435, 0.9439]
kb0_proportional_macro = [0.4264, 0.7373, 0.8021, 0.8670, 0.8775, 0.8930, 0.8971, 0.9054, 0.9064]
kb0_proportional_micro_std = [0.0740, 0.0245, 0.0112, 0.0039, 0.0028, 0.0021, 0.0017, 0.0015, 0.0016]
kb0_proportional_macro_std = [0.1008, 0.0689, 0.0465, 0.0090, 0.0055, 0.0037, 0.0031, 0.0028, 0.0029]

#---------------------------
#Results for svc_proportional

svc_proportional_micro = [0.6596, 0.8234, 0.8660, 0.9274, 0.9430, 0.9626, 0.9673, 0.9746, 0.9753]
svc_proportional_macro = [0.3792, 0.5865, 0.6704, 0.8420, 0.8860, 0.9342, 0.9441, 0.9584, 0.9597]
svc_proportional_micro_std = [0.0827, 0.0334, 0.0163, 0.0056, 0.0028, 0.0016, 0.0013, 0.0012, 0.0012]
svc_proportional_macro_std = [0.0837, 0.0647, 0.0423, 0.0192, 0.0092, 0.0033, 0.0026, 0.0020, 0.0020]

#---------------------------
#Results for kb2_balanced

kb2_balanced_micro = [0.5946, 0.8706, 0.8999, 0.9278, 0.9335, 0.9433]
kb2_balanced_macro = [0.5016, 0.8074, 0.8442, 0.8839, 0.8924, 0.9078]
kb2_balanced_micro_std = [0.0769, 0.0204, 0.0112, 0.0031, 0.0025, 0.0017]
kb2_balanced_macro_std = [0.0618, 0.0241, 0.0147, 0.0060, 0.0044, 0.0030]

#---------------------------
#Results for svc_balanced

svc_balanced_micro = [0.5780, 0.8219, 0.8715, 0.9265, 0.9382, 0.9560]
svc_balanced_macro = [0.4970, 0.7381, 0.7978, 0.8775, 0.8965, 0.9258]
svc_balanced_micro_std = [0.0861, 0.0353, 0.0174, 0.0050, 0.0034, 0.0019]
svc_balanced_macro_std = [0.0689, 0.0363, 0.0215, 0.0086, 0.0060, 0.0036]

#---------------------------
#Results for nb_proportional

nb_proportional_micro = [0.6756, 0.8487, 0.8738, 0.9079, 0.9203, 0.9425, 0.9486, 0.9548, 0.9550]
nb_proportional_macro = [0.4238, 0.6308, 0.6689, 0.7540, 0.7983, 0.8868, 0.9093, 0.9295, 0.9297]
nb_proportional_micro_std = [0.0827, 0.0290, 0.0188, 0.0066, 0.0046, 0.0023, 0.0019, 0.0015, 0.0015]
nb_proportional_macro_std = [0.0834, 0.0616, 0.0469, 0.0300, 0.0221, 0.0069, 0.0044, 0.0028, 0.0027]

#---------------------------
#Results for kb1_proportional

kb1_proportional_micro = [0.6304, 0.8213, 0.8737, 0.9215, 0.9298, 0.9422, 0.9459, 0.9532, 0.9539]
kb1_proportional_macro = [0.3003, 0.5790, 0.7018, 0.8432, 0.8681, 0.9002, 0.9083, 0.9233, 0.9250]
kb1_proportional_micro_std = [0.0993, 0.0490, 0.0281, 0.0056, 0.0035, 0.0020, 0.0016, 0.0013, 0.0013]
kb1_proportional_macro_std = [0.0862, 0.1119, 0.0699, 0.0216, 0.0115, 0.0042, 0.0030, 0.0026, 0.0025]

# %%
plt.title('Micro $F_1$ Score vs Training Set Size')
plt.ylabel('Micro $F_1$ Score')
plt.xlabel('Training Set Size')
plt.plot(training_set_sizes_proportional, nb_proportional_micro, '-o', label='Multinomial Naive Bayes')
plt.plot(training_set_sizes_proportional, svc_proportional_micro,'-s', label='Support Vector Machine')
plt.plot(training_set_sizes_proportional, kb2_proportional_micro, '-D', label='Knowledge Base Depth 2')
plt.xlim(1200, 60000)
plt.ylim(0.92, 0.98)
plt.xticks([1200, 10000, 20000, 30000, 40000, 50000, 60000])
plt.legend(loc='lower right')
plt.savefig('micro_f1_large_training.pdf', bbox_inches='tight')
plt.show()

# %%
plt.title('Micro $F_1$ Score vs Proportional Training Set Size')
plt.ylabel('Micro $F_1$ Score')
plt.xlabel('Proportional Training Set Size')

plt.plot(training_set_sizes_proportional, nb_proportional_micro, '-o', label='Multinomial Naive Bayes')
plt.plot(training_set_sizes_proportional, svc_proportional_micro, '-s', label='Support Vector Machine')
plt.plot(training_set_sizes_proportional, kb0_proportional_micro, '-D', label='Knowledge Base Depth 0')
plt.xlim(12, 1200)
plt.xticks([12, 200, 400, 600, 800, 1000, 1200])
plt.ylim(0.65, 0.975)
plt.legend(loc='lower right')
plt.savefig('micro_f1_small_training.pdf', bbox_inches='tight')
plt.show()

# %%
plt.title('Macro $F_1$ Score vs Training Set Size')
plt.ylabel('Macro $F_1$ Score')
plt.xlabel('Training Set Size')
plt.plot(training_set_sizes_proportional, nb_proportional_macro, '-o', label='Multinomial Naive Bayes')
plt.plot(training_set_sizes_proportional, svc_proportional_macro, '-s', label='Support Vector Machine')
plt.plot(training_set_sizes_proportional, kb2_proportional_macro, '-D', label='Knowledge Base Depth 2')
plt.xlim(1200, 60000)
plt.ylim(0.8, 0.975)
plt.xticks([1200, 10000, 20000, 30000, 40000, 50000, 60000])
plt.legend(loc='lower right')
plt.savefig('macro_f1_large_training.pdf', bbox_inches='tight')
plt.show()

# %%
plt.title('Macro $F_1$ Score vs Balanced Training Set Size')
plt.ylabel('Macro $F_1$ Score')
plt.xlabel('Balanced Training Set Size')

plt.plot(training_set_sizes_balanced, nb_balanced_macro, '-o', label='Multinomial Naive Bayes')
plt.plot(training_set_sizes_balanced, svc_balanced_macro, '-s', label='Support Vector Machine')
plt.plot(training_set_sizes_balanced, kb2_balanced_macro, '-D', label='Knowledge Base Depth 2')
plt.xlim(0, 1200)
plt.ylim(0.47, 0.95)
plt.xticks([12, 200, 400, 600, 800, 1000, 1200])
plt.legend(loc='lower right')
plt.savefig('macro_f1_small_training.pdf', bbox_inches='tight')
plt.show()

# %%
plt.title('Micro $F_1$ Score vs Balanced Training Set Size')
plt.ylabel('Micro $F_1$ Score')
plt.xlabel('Balanced Training Set Size')
plt.plot(training_set_sizes_balanced, kb0_balanced_micro, label='Knowledge Base Depth 0')
plt.plot(training_set_sizes_balanced, kb1_balanced_micro, label='Knowledge Base Depth 1')
plt.plot(training_set_sizes_balanced, kb2_balanced_micro, label='Knowledge Base Depth 2')
plt.xlim(60, 1200)
plt.ylim(0.87, 0.95)
plt.xticks([60, 200, 400, 600, 800, 1000, 1200])
plt.legend(loc='lower right')
plt.show()

# %%
plt.title('Macro $F_1$ Score vs Balanced Training Set Size')
plt.ylabel('Macro $F_1$ Score')
plt.xlabel('Balanced Training Set Size')

plt.plot(training_set_sizes_balanced, kb0_balanced_macro, label='Knowledge Base Depth 0')
plt.plot(training_set_sizes_balanced, kb1_balanced_macro, label='Knowledge Base Depth 1')
plt.plot(training_set_sizes_balanced, kb2_balanced_macro, label='Knowledge Base Depth 2')
plt.xlim(12, 1200)
plt.ylim(0.72, 0.95)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Look at number of dimensions in feature vector.

# %%
training_set_sizes_proportional = [12, 60, 120, 600, 1200, 6000, 12000, 60000, 72488]
bow_features = np.array([1192, 3422, 5529, 13479, 19867, 43783, 59851, 120745, 130560])
kb0_features = np.array([11] * 9)
kb1_features = np.array([286, 298, 299, 305, 306, 307, 308, 311, 312])
kb2_features = np.array([1949, 2222, 2299, 2413, 2463, 2544, 2570, 2613, 2623])

# %%
plt.title('Number of Features vs Training Set Size')
plt.ylabel('Number of Features (thousands)')
plt.xlabel('Training Set Size')

plt.plot(training_set_sizes_proportional, bow_features/1000, label='Bag of Words')
plt.plot(training_set_sizes_proportional, kb2_features/1000, label='Knowledge Base Depth 2')
plt.xlim(12, 60000)
plt.legend()
plt.savefig('nof_train_size.pdf', bbox_inches='tight')
plt.show()
