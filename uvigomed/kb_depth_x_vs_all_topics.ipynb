# %%
import matplotlib.pyplot as plt

train_sizes = [100, 200, 500, 1000, 2000, 5000]
depth_0_micro_f1 = [0.1046, 0.1094, 0.1690, 0.1817, 0.1993, 0.2113]
depth_1_micro_f1 = [0.1209, 0.1423, 0.2164, 0.2474, 0.2760, 0.3007]
depth_2_micro_f1 = [0.1275, 0.2059, 0.2547, 0.3193, 0.3468, 0.3759]
all_topics_micro_f1 = [0.3614, 0.4774, 0.5952, 0.6359, 0.6538, 0.6844]

plt.title('Knowledge Base Embedding Comparison on UVigoMED')
plt.ylabel('Micro $F_1$ Score')
plt.xlabel('Training Set Size')

plt.plot(train_sizes, depth_0_micro_f1, '-^', label='Knowledge Base Depth 0')
plt.plot(train_sizes, depth_1_micro_f1, '-s', label='Knowledge Base Depth 1')
plt.plot(train_sizes, depth_2_micro_f1, '-D', label='Knowledge Base Depth 2')
plt.plot(train_sizes, all_topics_micro_f1, '-o', label='Knowledge Base All Topics')
plt.xticks([100, 1000, 2000, 3000, 4000, 5000])
plt.ylim(0.08, 1.0)
plt.legend(loc='upper left')
plt.savefig('depth_x_vs_all_topics_uvigomed.pdf', bbox_inches='tight')
plt.show()
